# %% [markdown]
# <h2>What is Factorial ?</h2>
#
# <h5>Factorial is the product of n numbers until it reaches up to 1. It we want to calculate the factorial of n, then we multiply the number less than or equal to n until it encounters 1. In other words, the multiplication of 1 to n is called the factorial of n.
#
# The factorial of the number n can be also defined as the product of the number n and the factorial (n -1).</h5>

# %% [markdown]
# <h2> Factorial Program </h2>

# %%
num = int(input("Enter your number: "))
fact = 1

if num < 0:
    print("Factorial of a negative number does not exist")
elif num == 0:
    print("Factorial of 0 is 1")
else:
    for i in range(1, num + 1):
        fact = fact * i
    print("Factorial of the given number is", fact)
# Out:
# Enter your number: 6
# Factorial of the given number is 720

# %% [markdown]
# <h2>To calculate a factorial you need to know two things:</h2>
#
# *  0! = 1
# *  n! = (n - 1)! × n
#
# The factorial of 0 has value of 1, and the factorial of a number n is equal to the multiplication between the number n and the factorial of n-1.
#
# For example, 5! is equal to 4! × 5.

# %% [markdown]
# ![program-for-factorial-of-a-number-1024x512.png](data:image/png;base64,...)
