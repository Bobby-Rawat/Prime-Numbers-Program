# %% [markdown]
# <h1>Star Patterns</h1>
# Star pattern in python is a way of printing stars (*) in different shapes using nested loops. The outer loop controls the number of rows, while the inner loop controls the number of columns. The number of stars and whitespaces in each row depends on the logic of the program. A basic example of star pattern is printing a rectangle of stars.

# %% [markdown]
# <h2> The Program Logic : </h2>
# Normally we use nested for loops to print star shapes in Python.
#
# For example, the following Python program will need two nested for loops. The outer for loop is for rows and the inner for loop is for columns or stars.
#
# We use first for loop from 1 to N where N is the number of rows. Similarly, second for loop is used to print stars. We know that there is only one star in first row. There are two stars in line number two and so on. Hence we use second for loop from 1 to i. where i is the row number.

# %%
num = int(input("Enter a Number : "))

for i in range(1, num+1):
    for j in range(1, i+1):
        print("*",end="")
    print()
# Out:
# Enter a Number : 5
# *
# **
# ***
# ****
# *****

# %% [markdown]
# <h2>Conclusion</h2>
#
# Coding star pattern in python is an engaging and educational exercise that helps hone programming skills. From simple triangles to intricate designs, the world of star pattern python can be both fun and challenging. This guide should assist you in understanding the fundamentals and embarking on your creative journey. Don’t hesitate to get help with python if you’re facing challenges, as it’s a part of the learning process. If you understand and work on the logic, these star patterns are easy to learn. All you then have to do is practice the programs multiple times to achieve expertise on this topic.
